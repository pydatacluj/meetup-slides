# %%
import networkx as nx
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (20, 10)

G = nx.Graph()

G.add_edge(1, 2)
G.add_edge(1, 5)
G.add_edge(3, 2)
G.add_edge(4, 2)
G.add_edge(5, 3)

nx.draw(G, with_labels=True)
plt.show()

# %%
sorted(G.nodes())
# Out:
# [1, 2, 3, 4, 5]

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 5), (2, 3), (2, 4), (5, 3)])

# %% [markdown]
# # Random graphs
# #### https://networkx.github.io/documentation/stable/reference/generators.html

# %%
G = nx.newman_watts_strogatz_graph(100, 5, 0.2)
# G = nx.barbell_graph(10, 1)

nx.draw(G, with_labels=True)
plt.show()

# %%
from nxviz import CircosPlot

c = CircosPlot(G, figsize=(15, 10))

c.draw()

plt.show()

# %% [markdown]
# # CircusPlot with classes
# <img src="images/1.png" width="1000">
#
# ##### https://medium.com/@Marianattestad/a-treatise-on-making-circos-plots-from-genomic-data-7ff496849e0

# %%
from nxviz import ArcPlot

# Create the un-customized ArcPlot object: a
a = ArcPlot(G, figsize=(15, 20))

# Draw a to the screen
a.draw()

# Display the plot
plt.show()

# %% [markdown]
# # ArcPlot with classes
# ![alt text](images/2.png "Arcplot")
# ##### https://blog.revolutionanalytics.com/2013/02/visualizing-networks-in-r-arc-diagrams-and-hive-plots.html
